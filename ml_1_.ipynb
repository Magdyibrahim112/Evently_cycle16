# %% [markdown]
# <a href="https://colab.research.google.com/github/Magdyibrahim112/Evently_cycle16/blob/development/ml_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

base_path = "/content/ML-project"

folders = [
    "data",
    "notebooks",
    "results"
]

os.makedirs(base_path, exist_ok=True)

for folder in folders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

os.listdir(base_path)
# Out:
# ['data', 'results', 'notebooks']
